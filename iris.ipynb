# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
from segmentator import *

# %%
IRIS_DIR = "eyes"
image_files = util.get_files(IRIS_DIR, "bmp")

image_raw = cv2.imread(image_files[0])

segmentator = IrisSegmentator(image_raw)
segmentator.display_extraction()
# Out:
# Contours found: 1
# Contours found: 4

# %%
IRIS_DIR = "eyes"
image_files = util.get_files(IRIS_DIR, "bmp")
for i in range(0, 20, 4):
    image_raw = cv2.imread(image_files[i])
    segmentator = IrisSegmentator(image_raw)
    segmentator.display_extraction()
# Out:
# Contours found: 1
# Contours found: 4
# Contours found: 1
# Contours found: 4
# Contours found: 1
# Contours found: 6
# Contours found: 1
# Contours found: 10
# Contours found: 1
# Contours found: 8
