# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
from segmentator import *

# %%
IRIS_DIR = "teczowka_data"
image_files = util.get_image_files(IRIS_DIR)

image =  cv2.imread(image_files[20])

segmentator = IrisSegmentator(image)
segmentator.display_extraction()
# Out:
# Contours found: 15
# Contours found: 6

# %%
IRIS_DIR = "eyes"
image_files = util.get_files(IRIS_DIR, "bmp")

image_raw = cv2.imread(image_files[1])

segmentator = IrisSegmentator(image_raw)
segmentator.display_extraction()
# Out:
# Contours found: 1
# Contours found: 2

# %%
IRIS_DIR = "eyes"
image_files = util.get_files(IRIS_DIR, "bmp")
for i in range(0, 50, 5):
    image_raw = cv2.imread(image_files[i])
    segmentator = IrisSegmentator(image_raw)
    segmentator.display_extraction()
# Out:
# Contours found: 1
# Contours found: 2
# Contours found: 1
# Contours found: 2
# Contours found: 1
# Contours found: 2
# Contours found: 1
# Contours found: 2
# Contours found: 1
# Contours found: 2
# Contours found: 2
# Contours found: 2
# Contours found: 1
# Contours found: 1
# Contours found: 4
# Contours found: 1
# Contours found: 3
# Contours found: 1
# Contours found: 1
# Contours found: 1
